# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51638/AIML-LAB/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
from sklearn.datasets import fetch_openml
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fetch_openml(data_id=5).keys
# Out:
# <function Bunch.keys>

# %%
from sklearn.datasets import fetch_openml

car_data = fetch_openml(name='car', version=2,
                        parser='auto')

# %%
type(car_data)
# Out:
# sklearn.utils._bunch.Bunch

# %%
car_data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
car_data.feature_names, car_data.target.value_counts()
# Out:
# (['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'],
#  binaryClass
#  P    1210
#  N     518
#  Name: count, dtype: int64)

# %%
# Data description

print(car_data.DESCR)
# Out:
# **Author**:
# **Source**: Unknown - Date unknown
# **Please cite**:
#
# Binarized version of the original data set (see version 1). The multi-class target feature is converted to a two-class nominal target feature by re-labeling the majority class as positive ('P') and all others as negative ('N'). Originally converted by Quan Sun.
#
# Downloaded from openml.org.

# %%
# Displaying feature names

car_data.feature_names
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety']

# %%
# Getting the whole dataframe
car_data = car_data.frame
car_data.head()
# Out:
#   buying  maint doors persons lug_boot safety binaryClass
# 0  vhigh  vhigh     2       2    small    low           P
# 1  vhigh  vhigh     2       2    small    med           P
# 2  vhigh  vhigh     2       2    small   high           P
# 3  vhigh  vhigh     2       2      med    low           P
# 4  vhigh  vhigh     2       2      med    med           P

# %%
type(car_data)
# Out:
# pandas.core.frame.DataFrame

# %%
#car_data.columns
l = len(car_data.columns)
for i in range(l):
  sns.jointplot(x=car_data.columns[i],y='binaryClass',
                data=car_data,palette='rainbow')

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(car_data, test_size=0.2,
                                         random_state=220)

                                         #print('Dataset size:{}\ntraining data is: {}\n
                                         #testing data is: {}'.format(len(car_data),
                                         #len(train_data),len(test_data)))
car_data.shape, train_data.shape, test_data.shape
# Out:
# ((1728, 7), (1382, 7), (346, 7))

# %%
from sklearn.model_selection import train_test_split

# Splitting the data into training and testing sets
train_data, test_data = train_test_split(car_data, test_size=0.2, random_state=220)

# Printing the dataset sizes and shapes
print("Dataset size: {}\nTraining data size: {}\nTesting data size: {}".format(
len(car_data), len(train_data), len(test_data)))
print("car_data shape:", car_data.shape)
print("train_data shape:", train_data.shape)
# Out:
# Dataset size: 1728
# Training data size: 1382
# Testing data size: 346
# car_data shape: (1728, 7)
# train_data shape: (1382, 7)

# %%
# Checking summary statistics

train_data.describe()
# Out:
#        buying maint doors persons lug_boot safety binaryClass
# count    1382  1382  1382    1382     1382   1382        1382
# unique      4     4     4       3        3      3           2
# top     vhigh   med     2       2    small   high           P
# freq      356   355   352     476      478    468         972

# %%
# Checking missing values
train_data.isnull().sum()
# Out:
# buying         0
# maint          0
# doors          0
# persons        0
# lug_boot       0
# safety         0
# binaryClass    0
# dtype: int64

# %%
train_data.columns
# Out:
# Index(['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety',
#        'binaryClass'],
#       dtype='object')

# %%
train_data['buying'].value_counts()
# Out:
# buying
# vhigh    356
# low      349
# med      339
# high     338
# Name: count, dtype: int64

# %%
train_data['maint'].value_counts()
# Out:
# maint
# med      355
# vhigh    347
# low      344
# high     336
# Name: count, dtype: int64

# %%
train_data['doors'].value_counts()
# Out:
# doors
# 2        352
# 5more    347
# 3        342
# 4        341
# Name: count, dtype: int64

# %%
train_data['persons'].value_counts()
# Out:
# persons
# 2       476
# 4       455
# more    451
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='buying')
# Out:
# <Axes: xlabel='buying', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='buying', hue='binaryClass')
# Out:
# <Axes: xlabel='buying', ylabel='count'>

# %%
train_data['maint'].value_counts()
# Out:
# maint
# med      355
# vhigh    347
# low      344
# high     336
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='maint')
# Out:
# <Axes: xlabel='maint', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='maint', hue='binaryClass')
# Out:
# <Axes: xlabel='maint', ylabel='count'>

# %%
train_data['doors'].value_counts()
# Out:
# doors
# 2        352
# 5more    347
# 3        342
# 4        341
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='doors')
# Out:
# <Axes: xlabel='doors', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='doors', hue='binaryClass')
# Out:
# <Axes: xlabel='doors', ylabel='count'>

# %%
train_data['persons'].value_counts()
# Out:
# persons
# 2       476
# 4       455
# more    451
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='persons', hue='binaryClass')
# Out:
# <Axes: xlabel='persons', ylabel='count'>

# %%
train_data['lug_boot'].value_counts()
# Out:
# lug_boot
# small    478
# med      466
# big      438
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='lug_boot', hue='binaryClass')
# Out:
# <Axes: xlabel='lug_boot', ylabel='count'>

# %%
train_data['safety'].value_counts()
# Out:
# safety
# high    468
# med     462
# low     452
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='safety', hue='binaryClass')plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='safety', hue='binaryClass')
# Out:
# <Axes: xlabel='safety', ylabel='count'>

# %%
train_data['binaryClass'].value_counts()
# Out:
# binaryClass
# P    972
# N    410
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='binaryClass')
# Out:
# <Axes: xlabel='binaryClass', ylabel='count'>

# %%
car_train = train_data.drop('binaryClass', axis=1)
car_labels = train_data[['binaryClass']]

# %%
from sklearn.preprocessing import OrdinalEncoder

from sklearn.pipeline import Pipeline

pipe = Pipeline([('ord_enc', OrdinalEncoder())])

car_train_prepared = pipe.fit_transform(car_train)

# %%
from sklearn.preprocessing import LabelEncoder

label_enc = LabelEncoder()

car_labels_prepared = label_enc.fit_transform(car_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
car_train_prepared.shape, car_labels_prepared.shape
# Out:
# ((1382, 6), (1382,))

# %%
from sklearn.tree import DecisionTreeClassifier

tree_clf = DecisionTreeClassifier()
tree_clf.set_params(class_weight='balanced', criterion='entropy')

tree_clf.fit(car_train_prepared, car_labels_prepared)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy')

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20,15))
plot_tree(tree_clf, feature_names=car_train.columns,
          class_names=['N','P']);

          from sklearn.tree import plot_tree

          plt.figure(figsize=(20,15))
          plot_tree(tree_clf, feature_names=car_train.columns,
                    class_names=['N','P']);

                    class_names=['N','P']);

# %%
# if you run this, it will be error.
# SKlearn tree implementation doesn't support categorical features

#from sklearn.tree import DecisionTreeClassifier

#tree_clf = DecisionTreeClassifier()

#tree_clf.fit(car_train, car_labels)

# %%
from sklearn.metrics import accuracy_score, classification_report,\
confusion_matrix

preds = tree_clf.predict(car_train_prepared)
print(f"Accuracy:{accuracy_score(car_labels_prepared, preds)}")
print(f"ClassReport:{classification_report(car_labels_prepared,preds)}")
print(f"Confusion Matrix:{confusion_matrix(car_labels_prepared,preds)}")
# Out:
# Accuracy:1.0
# ClassReport:              precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       410
#            1       1.00      1.00      1.00       972
#
#     accuracy                           1.00      1382
#    macro avg       1.00      1.00      1.00      1382
# weighted avg       1.00      1.00      1.00      1382
#
# Confusion Matrix:[[410   0]
#  [  0 972]]

# %%
accuracy_score(car_labels_prepared,preds)
# Out:
# 1.0

# %%
tree_clf.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
# Let's hide warnings returned by grid search

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import GridSearchCV

params_grid = {'max_leaf_nodes': list(range(0, 10)),
               'min_samples_split': [0,1,2, 3, 4],
                              'min_samples_leaf': [0,1,2, 3, 4],
                                             'max_depth':[0,1,2,3,4,5],
                                                            'max_features':[0,1,2,3,4,5],
                                                                          'max_leaf_nodes':[0,1,2,3,4,5]}

                                                                          #refit is true by default. The best estimator is trained on the whole dataset

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier # Assuming you are using DecisionTreeClassifier

# Assuming 'car_labels_prepared' and some feature data 'X' are defined

params_grid = {'max_leaf_nodes': list(range(0, 10)),
               'min_samples_split': [0,1,2, 3, 4],
               'min_samples_leaf': [0,1,2, 3, 4],
               'max_depth':[0,1,2,3,4,5],
               'max_features':[0,1,2,3,4,5],
               'max_leaf_nodes':[0,1,2,3,4,5]}

# Create a DecisionTreeClassifier instance
tree_clf = DecisionTreeClassifier()

# Create GridSearchCV instance and assign it to grid_search
grid_search = GridSearchCV(tree_clf, params_grid, cv=5) # Assuming 5-fold cross-validation

# Fit the model
grid_search.fit(car_train_prepared, car_labels_prepared) # Replace 'X' with your feature data

# Now you can access best_params_
grid_search.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 5,
#  'max_leaf_nodes': 5,
#  'min_samples_leaf': 1,
#  'min_samples_split': 3}

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=5, max_features=5, max_leaf_nodes=5,
#                        min_samples_split=3)

# %%
tree_best = grid_search.best_estimator_

# %%
car_data.columns
# Out:
# Index(['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety',
#        'binaryClass'],
#       dtype='object')

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20,15))
plot_tree(tree_best, feature_names=car_train.columns, class_names=['N','P']);

# %%
accuracy(car_train_prepared, tree_best, car_labels_prepared)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-2055825dedef> in <cell line: 1>()
# ----> 1 accuracy(car_train_prepared, tree_best, car_labels_prepared)
#
# NameError: name 'accuracy' is not defined

# %%
from sklearn.metrics import accuracy_score

# Get predictions for the training data
train_predictions = tree_best.predict(car_train_prepared)

# Calculate accuracy
accuracy = accuracy_score(car_labels_prepared, train_predictions)
print("Accuracy on training data:", accuracy)
# Out:
# Accuracy on training data: 0.8791606367583212

# %%
conf_matrix(car_train_prepared, tree_best, car_labels_prepared)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-85368d0cd3f1> in <cell line: 1>()
# ----> 1 conf_matrix(car_train_prepared, tree_best, car_labels_prepared)
#
# NameError: name 'conf_matrix' is not defined

# %%
from sklearn.metrics import confusion_matrix

# Get predictions for the training data
train_predictions = tree_best.predict(car_train_prepared)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(car_labels_prepared, train_predictions)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Confusion Matrix:
#  [[390  20]
#  [147 825]]

# %%
class_report(car_train_prepared, tree_best, car_labels_prepared)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-627fe8456af3> in <cell line: 1>()
# ----> 1 class_report(car_train_prepared, tree_best, car_labels_prepared)
#
# NameError: name 'class_report' is not defined

# %%
from sklearn.metrics import classification_report

# Get predictions for the training data
train_predictions = tree_best.predict(car_train_prepared)

# Generate the classification report
class_report = classification_report(car_labels_prepared, train_predictions)
print("Classification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.95      0.82       410
#            1       0.98      0.85      0.91       972
#
#     accuracy                           0.88      1382
#    macro avg       0.85      0.90      0.87      1382
# weighted avg       0.90      0.88      0.88      1382

# %%
car_test = test_data.drop('binaryClass', axis=1)
car_test_labels = test_data['binaryClass']

# %%
# Handling the categorical features with the pipeline that we defined early
# We don't fit on the test data. Only transform

car_test_prepared = pipe.transform(car_test)

# %%
# Handle labels too

car_test_labels_prepared = label_enc.transform(car_test_labels)

# %%
accuracy(car_test_prepared, tree_best, car_test_labels_prepared)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-efdeddcba9e7> in <cell line: 1>()
# ----> 1 accuracy(car_test_prepared, tree_best, car_test_labels_prepared)
#
# TypeError: 'float' object is not callable

# %%
from sklearn.metrics import accuracy_score

# Get predictions for the test data
test_predictions = tree_best.predict(car_test_prepared)

# Calculate accuracy on the test data
accuracy = accuracy_score(car_test_labels_prepared, test_predictions)
print("Accuracy on test data:", accuracy)
# Out:
# Accuracy on test data: 0.8872832369942196

# %%
conf_matrix(car_test_prepared, tree_best, car_test_labels_prepared)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-4c2173c62b39> in <cell line: 1>()
# ----> 1 conf_matrix(car_test_prepared, tree_best, car_test_labels_prepared)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
from sklearn.metrics import confusion_matrix

# Get predictions for the test data
test_predictions = tree_best.predict(car_test_prepared)

# Calculate the confusion matrix for the test data
conf_matrix = confusion_matrix(car_test_labels_prepared, test_predictions)
print("Confusion Matrix on test data:\n", conf_matrix)
# Out:
# Confusion Matrix on test data:
#  [[102   6]
#  [ 33 205]]

# %%
class_report(car_test_prepared, tree_best, car_test_labels_prepared)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-2c83eca9f864> in <cell line: 1>()
# ----> 1 class_report(car_test_prepared, tree_best, car_test_labels_prepared)
#
# TypeError: 'str' object is not callable

# %%
from sklearn.metrics import classification_report

# Get predictions for the test data
test_predictions = tree_best.predict(car_test_prepared)

# Generate the classification report for the test data
class_report = classification_report(car_test_labels_prepared, test_predictions)
print("Classification Report on test data:\n", class_report)
# Out:
# Classification Report on test data:
#                precision    recall  f1-score   support
#
#            0       0.76      0.94      0.84       108
#            1       0.97      0.86      0.91       238
#
#     accuracy                           0.89       346
#    macro avg       0.86      0.90      0.88       346
# weighted avg       0.90      0.89      0.89       346
